# %%
import sys
sys.path.append('../shap')
import shap

import os
sys.path.append('../..')
import numpy as np
import deepbayesHF
import deepbayesHF.optimizers as optimizers
from deepbayesHF import PosteriorModel
from deepbayesHF.analyzers import FGSM
from deepbayesHF.analyzers import eps_LRP
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
import cv2
import random
import matplotlib.pyplot as plt
from collections import namedtuple

from joblib import Parallel, delayed
import subprocess
from statistics import mode
import json
import tensorflow as tf

# %%
def display_number(X):
    X = X.reshape(X.shape[1],X.shape[2])
    plt.imshow(X,cmap='gray')
    plt.show()

# %%
# load mnist data
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.reshape(60000,28,28,1)
X_train = X_train/255.
X_train = X_train.astype("float32")

X_test = X_test.reshape(10000,28,28,1)
X_test = X_test/255.
X_test = X_test.astype("float32")

# %%
model_name = f'MNIST_SHAP_fullsize'

opt = optimizers.VariationalOnlineGuassNewton()
likelihood = tf.keras.losses.SparseCategoricalCrossentropy()

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

bayes_model = opt.compile(model,loss_fn=likelihood,
                          epochs=25, learning_rate=0.25,
                          inflate_prior=2.0, log_file='tmp/log.txt')

bayes_model.train(X_train,y_train,X_test,y_test)
bayes_model.save(model_name)
# Out:
# This optimizer does not have a default compilation method. Please make sure to call the correct .compile method before use.
# deepbayes: Using implicit prior
# (3, 3, 1, 32) 0.4714045207910317
# (3, 3, 32, 64) 0.08333333333333333
# (9216, 128) 0.01473139127471974
# (128, 10) 0.125
# deepbayes: Using implicit prior
# (3, 3, 1, 32) 0.4714045207910317
# (3, 3, 32, 64) 0.08333333333333333
# (9216, 128) 0.01473139127471974
# (128, 10) 0.125
# 100%|██████████| 938/938 [00:57<00:00, 16.29it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 1, loss: 0.711, acc: 0.809, val_loss: 0.216, val_acc: 0.936
# 100%|██████████| 938/938 [00:56<00:00, 16.69it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 2, loss: 0.145, acc: 0.958, val_loss: 0.081, val_acc: 0.976
# 100%|██████████| 938/938 [00:56<00:00, 16.55it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 3, loss: 0.072, acc: 0.978, val_loss: 0.058, val_acc: 0.983
# 100%|██████████| 938/938 [00:56<00:00, 16.49it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 4, loss: 0.049, acc: 0.984, val_loss: 0.054, val_acc: 0.983
# 100%|██████████| 938/938 [00:57<00:00, 16.18it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 5, loss: 0.031, acc: 0.990, val_loss: 0.043, val_acc: 0.987
# 100%|██████████| 938/938 [00:58<00:00, 15.97it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 6, loss: 0.019, acc: 0.994, val_loss: 0.051, val_acc: 0.987
# 100%|██████████| 938/938 [00:58<00:00, 15.99it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 7, loss: 0.018, acc: 0.994, val_loss: 0.050, val_acc: 0.988
# 100%|██████████| 938/938 [00:58<00:00, 16.07it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 8, loss: 0.019, acc: 0.994, val_loss: 0.067, val_acc: 0.985
# 100%|██████████| 938/938 [00:57<00:00, 16.25it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 9, loss: 0.016, acc: 0.995, val_loss: 0.055, val_acc: 0.987
# 100%|██████████| 938/938 [00:57<00:00, 16.18it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 10, loss: 0.022, acc: 0.993, val_loss: 0.078, val_acc: 0.982
# 100%|██████████| 938/938 [00:58<00:00, 16.15it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 11, loss: 0.019, acc: 0.994, val_loss: 0.056, val_acc: 0.986
# 100%|██████████| 938/938 [00:56<00:00, 16.49it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 12, loss: 0.013, acc: 0.996, val_loss: 0.050, val_acc: 0.989
# 100%|██████████| 938/938 [00:57<00:00, 16.33it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 13, loss: 0.009, acc: 0.997, val_loss: 0.052, val_acc: 0.989
# 100%|██████████| 938/938 [00:57<00:00, 16.20it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 14, loss: 0.009, acc: 0.997, val_loss: 0.060, val_acc: 0.988
# 100%|██████████| 938/938 [00:57<00:00, 16.40it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 15, loss: 0.010, acc: 0.997, val_loss: 0.055, val_acc: 0.988
# 100%|██████████| 938/938 [00:56<00:00, 16.55it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 16, loss: 0.008, acc: 0.998, val_loss: 0.055, val_acc: 0.987
# 100%|██████████| 938/938 [00:57<00:00, 16.30it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 17, loss: 0.008, acc: 0.998, val_loss: 0.050, val_acc: 0.990
# 100%|██████████| 938/938 [00:57<00:00, 16.34it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 18, loss: 0.005, acc: 0.998, val_loss: 0.051, val_acc: 0.989
# 100%|██████████| 938/938 [00:57<00:00, 16.34it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 19, loss: 0.004, acc: 0.999, val_loss: 0.054, val_acc: 0.989
# 100%|██████████| 938/938 [00:57<00:00, 16.24it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 20, loss: 0.004, acc: 0.999, val_loss: 0.057, val_acc: 0.989
# 100%|██████████| 938/938 [00:57<00:00, 16.22it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 21, loss: 0.003, acc: 0.999, val_loss: 0.055, val_acc: 0.987
# 100%|██████████| 938/938 [00:57<00:00, 16.43it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 22, loss: 0.003, acc: 0.999, val_loss: 0.059, val_acc: 0.988
# 100%|██████████| 938/938 [00:57<00:00, 16.36it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 23, loss: 0.002, acc: 1.000, val_loss: 0.056, val_acc: 0.988
# 100%|██████████| 938/938 [00:57<00:00, 16.40it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 24, loss: 0.003, acc: 0.999, val_loss: 0.057, val_acc: 0.989
# 100%|██████████| 938/938 [00:58<00:00, 16.13it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 25, loss: 0.004, acc: 0.999, val_loss: 0.059, val_acc: 0.989
# 100%|██████████| 938/938 [00:57<00:00, 16.39it/s]
# Epoch 26, loss: 0.004, acc: 0.999, val_loss: 0.063, val_acc: 0.987
# ('batch_size', 64)
# ('learning_rate', 0.25)
# ('decay', 0.0)
# ('epochs', 26)
# ('inflate_prior', 2.0)
# ('input_noise', 0.0)
# ('robust_train', 0)
# ('epsilon', 0.1)
# ('robust_lambda', 0.5)
# ('loss_monte_carlo', 2)
# ('input_upper', inf)
# ('input_lower', -inf)
# ('beta_1', 0.999)
# ('beta_2', 0.9999)
# ('lam', 1.0)
# ('N', 60000)
# ('max_eps', 0.1)
# ('max_robust_lambda', 0.5)

# %%
model_name = f'MNIST_SHAP_fullsize'
bayes_model = PosteriorModel(model_name)
y_pred = bayes_model.predict(X_test[:50],n=50)
check_accuracy = tf.keras.metrics.Accuracy(name="train_acc")
check_accuracy(y_test[:50],np.argmax(y_pred,axis=1))
print()
print('Loaded model accuracy:',f'{check_accuracy.result().numpy()*100:.2f}%')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1179776
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________
# deepbayes: detected the above model
#  None
#
# Loaded model accuracy: 100.00%

# %%
N = 50
# pick a random correctly classified input for testing
n = 0
while True:
    n = np.random.randint(len(y_train))
    X = X_train[n].reshape(1,SCALE[0],SCALE[1],1).astype(float)
    y_hat = np.argmax(bayes_model.predict(X,n=N))
    y_class = y_hat
    if y_hat == y_train[n]:
        break
        
display_number(X)
print('Prediction:',y_class)
input_shape = X.flatten().shape

print("Index:",n)
# Out:
# Prediction: 3
# Index: 33169

# %%
#background = X_train[np.random.choice(X_train.shape[0],100,replace=False)]
#bayes_model.set_weights(bayes_model.sample())
#model = bayes_model.model
#e = shap.DeepExplainer(model,background)
#shap_values = e.shap_values(X)

# %%
#print(X.shape)
#print(shap_values[0].shape)
#shap.image_plot(shap_values,-X)

# %%
background = X_train[np.random.choice(X_train.shape[0],200,replace=False)]

if not os.path.exists(f'exps/exp{n}'):
    os.mkdir(f'exps/exp{n}')
    
input_path = f'exps/exp{n}/X.npy'
background_path = f'exps/exp{n}/bg.npy'
np.save(input_path,X,False)
np.save(background_path,background,False)

iterations = 10
for i in range(iterations):
    subprocess.Popen(['python3','get_SHAP_exp.py',str(i),model_name,input_path,f'exps/exp{n}',background_path])
        
full = False 
while not full:
    if len([name for name in os.listdir(f'exps/exp{n}') if os.path.isfile(os.path.join(f'exps/exp{n}', name))]) == iterations+2:
        full = True

# %% [markdown]
# ## Display All Explanations From Sampled BNNs

# %%
# read in and display the results from the above
ns = [33169]

exps_per_ns = dict()
for n in ns:
    exps = []
    for f in os.listdir(f'exps/exp{n}'):
        if os.path.isfile(os.path.join(f'exps/exp{n}',f)) and not f.startswith('X') and not f.startswith('bg'):
            tmp = np.load(os.path.join(f'exps/exp{n}',f))
            # the shap.image_plot function only works with an outer list, not np array (no idea why, its the same shape)
            tmp = [tmp[i] for i in range(tmp.shape[0])]
            exps.append(tmp)

    X = np.load(f'exps/exp{n}/X.npy')
    for exs in exps:
        shap.image_plot(exs, -X)
    exps_per_ns[n] = exps.copy()
    print('==============================================')
# Out:
# ==============================================

# %%
N = 50
n = 0
while True:
    n = np.random.randint(0,len(y_train))
    print(n)
    
    X = X_train[n].reshape(1,28,28,1).astype(float)
    
    ##### GET UNCERT INPUT THAT IS CORRECTLY CLASSIFIED
    
    bayes_model.set_weights(bayes_model.sample())
    prediction = [np.array(bayes_model._predict(X))[0]]
    for i in range(N-1):
        bayes_model.set_weights(bayes_model.sample())
        prediction.append(np.array(bayes_model._predict(X))[0])
    y_hat_ls = list(np.argmax(prediction,axis=1))
    y_hat = mode(y_hat_ls)
    if y_hat_ls.count(y_hat) < 0.6*50 and y_train[n] == y_hat:
        print(y_hat)
        print(y_hat_ls)
        break
    
        
    '''
    if y_train[n] != y_hat:
        break
    '''

display_number(X)
print('Prediction:',y_hat)
print(y_hat_ls)
input_shape = X.flatten().shape

print("Index:",n)
# Out:
# 1432
# 46577
# 42447
# 43947
# 52092
# 50412
# 13382
# 58701
# 57300
# 19730
# 44166
# 57586
# 35295

# %%
background = X_train[np.random.choice(X_train.shape[0],200,replace=False)]

if not os.path.exists(f'exps/exp{n}'):
    os.mkdir(f'exps/exp{n}')
    
input_path = f'exps/exp{n}/X.npy'
background_path = f'exps/exp{n}/bg.npy'
np.save(input_path,X,False)
np.save(background_path,background,False)

iterations = 10
for i in range(iterations):
    subprocess.Popen(['python3','get_SHAP_exp.py',str(i),model_name,input_path,f'exps/exp{n}',background_path])
        
full = False 
while not full:
    if len([name for name in os.listdir(f'exps/exp{n}') if os.path.isfile(os.path.join(f'exps/exp{n}', name))]) == iterations+2:
        full = True

# %%
# read in and display the results from the above
ns = [46726]

exps_per_ns = dict()
for n in ns:
    exps = []
    for f in os.listdir(f'exps/exp{n}'):
        if os.path.isfile(os.path.join(f'exps/exp{n}',f)) and not f.startswith('X') and not f.startswith('bg'):
            tmp = np.load(os.path.join(f'exps/exp{n}',f))
            # the shap.image_plot function only works with an outer list, not np array (no idea why, its the same shape)
            tmp = [tmp[i] for i in range(tmp.shape[0])]
            exps.append(tmp)

    X = np.load(f'exps/exp{n}/X.npy')
    for exs in exps:
        shap.image_plot(exs, -X)
    exps_per_ns[n] = exps.copy()
    print('==============================================')
# Out:
# ==============================================
