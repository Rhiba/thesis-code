# %%
import numpy as np
from os import listdir
from os.path import isfile, join

path = "back_log/"
files = [join(path, d) for d in listdir(path) if isfile(join(path, d))]

# %%
raw_data = np.load(files[0])

# %%
img = np.asarray(raw_data).reshape(720,1280,4)
img = img[:,:,:3]
img = img[:, :, ::-1]
img = cv2.resize(img, (64,48))
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

plt.imshow(img)
plt.show()

# %%
img = np.rollaxis(img, axis=-1)[0:3].reshape(1280,720,3)

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.resize(img,(64,48))

plt.imshow(img)
plt.show()
